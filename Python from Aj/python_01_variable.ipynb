# %% [markdown]
# **Variable**
#
# Rules for variable name
# * Can contain only a-z, A-Z, 0-9 and _
# * Cannot start with a number
# * Case sensitive
#
# Basic types of *simple* parameters
# * integer
# * float
# * string

# %%
# Assign variables
# Display values and types of variables
number_1 = 5
number_2 = 5.0
name = "abcde"
print(number_1)
print(type(number_1))
print(type(number_2))
print(type(name))
# Out:
# 5
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
# Type of variable is automatically assigned
x = 1
y = 1.0
z = "a"
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
# Integer (whole number) and Float (real number)
i1 = 5
i2 = -3
print(i1)
print(i2)
print(type(i1))

f1 = 1.0
f2 = -35.9
f3 = 1.35e-7
print(f1)
print(f2)
print(f3)
print(type(f1))
# Out:
# 5
# -3
# <class 'int'>
# 1.0
# -35.9
# 1.35e-07
# <class 'float'>

# %%
# Python integer *cannot* overflow
# Float can be too large (overflow) or too small (underflow)
largeint = 10**1000
print(largeint)

largefloat1 = 1.0e300
largefloat2 = 1.0e500
print(largefloat1)
print(largefloat2)

smallfloat1 = 1.0e-300
smallfloat2 = 1.0e-500
print(smallfloat1)
print(smallfloat2)
# Out:
# ...
# 1e+300
# inf
# 1e-300
# 0.0

# %%
# String is character data
x = "hello"
y = 'abc'
print(x)
print(type(x))
print(len(x))
# Out:
# hello
# <class 'str'>
# 5

# %%
# Changing (casting) variable type
i1 = int(2.8)
i2 = int("3")
f1 = float(1)
f2 = float("3")
f3 = float("3.5")
s1 = str(2)
s2 = str(3.3)
print(i1)
print(i2)
print(f1)
print(f2)
print(f3)
print(s1)
print(s2)
# Out:
# 2
# 3
# 1.0
# 3.0
# 3.5
# 2
# 3.3

# %%
# Get information on a variable
x = 1
help(x)
# Out:
# Help on int object:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
# ...
